# %% [markdown]
# # Analysis of Fermented Drink Data

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# Import Libraries and Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### 1.Display the data of white wine and red wine

# %%
# data of white wine
df_white = pd.read_csv('winequality-white.csv', sep=';')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# data of Red wine
df_red = pd.read_csv('winequality-red.csv', sep=';')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ##### 2.Get the size of both white wine and red wine.

# %%
print("Size of the Red Wine: ",df_red.size)
print("Size of the White Wine: ",df_white.size)
# Out:
# Size of the Red Wine:  19188
# Size of the White Wine:  58776

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ##### 3. Get the number of null in both type of wines

# %%
print("Number of null in Red wine: ",df_red.isnull().sum())
print('\n')
print("Number of null in White wine: ",df_white.isnull().sum())
# Out:
# Number of null in Red wine:  fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#
#
# Number of null in White wine:  fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ##### 4. Check for duplicates and remove them in both type of wine data

# %%
print('Number of Duplicated Values(white): ',sum(df_white.duplicated()))
print('Number of Duplicated Values(Red): ',sum(df_red.duplicated()))
df_white.drop_duplicates(inplace=True)
df_red.drop_duplicates(inplace=True)
# Out:
# Number of Duplicated Values(white):  937
# Number of Duplicated Values(Red):  240

# %% [markdown]
# ##### 5. Get the number of uniques values in all Feature and print them

# %%
df_red.nunique() # Get the number of uniques values in all Feature in Red Wine
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df_white.nunique()  # Get the number of uniques values in all Feature in White Wine
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %% [markdown]
# ##### 6. Print the mean density of both the sets

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %% [markdown]
# ##### 7. Combine both the datasets with color of the wine in column

# %%
#combine two data set
#First, add new column telling Red/White to preserve the characteristics.
#Creating two arrays using numpy as long as the number of rows in the red and white dataframes that repeat the value “red” or 
#“white.”and add that as a column into each dataframe.

color_red = np.repeat('red', 1359)
color_white = np.repeat('white', 3961)
color_red
# Out:
# array(['red', 'red', 'red', ..., 'red', 'red', 'red'], dtype='<U3')

# %%
df_red['color'] = color_red
df_white['color'] = color_white
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ##### 8. Remove the null values if any

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %% [markdown]
# ##### 9. Remove the outliers if any

# %%
#find outliers
q1 = df_red.quantile(.25)
q3 = df_red.quantile(.75)
iqr=q3-q1

upper = q3+1.5*iqr
lower = q1-1.5*iqr

outliers = (df_red>upper) | (df_red<lower)
outliers.sum()
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4258271034.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1 = df_red.quantile(.25)
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4258271034.py:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3 = df_red.quantile(.75)
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4258271034.py:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers = (df_red>upper) | (df_red<lower)
# ...

# %%
def cap_data(df):
    for col in df.columns:
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
            percentiles = df[col].quantile([.25,.75]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

cap_data(df_red)

# find or check outliers in Data Frame
q1 = df_red.quantile(.25)
q3 = df_red.quantile(.75)
iqr =  q3-q1
upper = q3+1.5*iqr
lower = q1-1.5*iqr

outliers = ((df_red>upper) | (df_red<lower)).sum()
outliers
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4060240757.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] <= percentiles[0]] = percentiles[0]
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4060240757.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] >= percentiles[1]] = percentiles[1]
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/4060240757.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sns.boxplot(df_red['residual sugar'])
# Out:
# C:\Users\omkar narkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='residual sugar'>

# %% [markdown]
# ##### 10. Do wines with higher alcohol content receive better ratings?

# %%
##### Combine DataFrames with Append() #####

df_wine = df_red.append(df_white, ignore_index=True)
df_wine
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/738729629.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wine = df_red.append(df_white, ignore_index=True)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.64         0.09             1.9      0.076
# 1               7.8              0.64         0.09             2.6      0.091
# 2               7.8              0.64         0.09             2.3      0.091
# 3               9.2              0.39         0.43             1.9      0.075
# 4               7.4              0.64         0.09             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# ...

# %%
# Use query to select each group and get its mean quality

a_median = df_wine['alcohol'].median()

a_low = df_wine.query('alcohol < {}'.format(a_median))
a_high = df_wine.query('alcohol >= {}'.format(a_median))

mean_qual_low = a_low['quality'].mean()
mean_qual_high = a_high['quality'].mean()

# %%
# Create a bar chart with proper labels

rangies = [1,2]
colors =['red','green']
heights = [mean_qual_low, mean_qual_high]
labels = ['Low', 'High']
plt.bar(rangies,heights, color =colors, tick_label = labels)

plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('alcohol Content')
plt.ylabel('Average Quality Rating')
# Out:
# Text(0, 0.5, 'Average Quality Rating')

# %% [markdown]
# Conclusion: As per bar graph we can conclude that, high alcohol containt gets high rating

# %% [markdown]
# ##### 11. Find correlation between citric acid content and PH.

# %%
df_wine['citric acid'].corr(df_wine['pH'])
# Out:
# -0.28944116434611217

# %%
sns.heatmap(df_wine.corr(), cmap="YlGnBu", annot=True)
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/2477571839.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_wine.corr(), cmap="YlGnBu", annot=True)
# <AxesSubplot:>

# %%
plt.scatter(df_wine['citric acid'], df_wine['pH'])

# %% [markdown]
# ##### 12. Find regression of PH on citric acid

# %%
sns.regplot(x = df_wine['pH'],
            y = df_wine['citric acid'], 
            ci = None,
            data = df_wine)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='citric acid'>

# %%
import statsmodels.api as sm

x = np.array(df_wine['pH'])
y = np.array(df_wine['citric acid'])

data = pd.DataFrame(y, x)

fit = sm.OLS(y,x).fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.843
# Model:                            OLS   Adj. R-squared (uncentered):              0.843
# Method:                 Least Squares   F-statistic:                          2.864e+04
# Date:                Tue, 21 Feb 2023   Prob (F-statistic):                        0.00
# Time:                        12:12:20   Log-Likelihood:                          3099.5
# No. Observations:                5320   AIC:                                     -6197.
# Df Residuals:                    5319   BIC:                                     -6190.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### 13. Find how many variables are independent.

# %%
import pandas as pd
import numpy as np
import scipy.stats
from scipy.stats import chi2

table = pd.crosstab(df_wine['quality'],df_wine['residual sugar'])
table
# Out:
# residual sugar  0.60   0.70   0.80   0.90   0.95   1.00   1.05   1.10   1.15   \
# quality
# 3                   0      1      0      0      0      0      0      0      1
# 4                   0      1      5      5      0      3      1      7      0
# 5                   1      3     11      7      3     28      0     30      1
# 6                   0      2      8     19      0     35      0     60      1
# 7                   0      0      0      4      0      8      0     25      0
# 8                   0      0      1      0      0      3      0      4      0
# 9                   0      0      0      0      0      0      0      0      0
#
# residual sugar  1.20   ...  20.30  20.40  20.70  20.80  22.00  22.60  23.50  \
# quality                ...
# 3                   1  ...      0      0      0      0      0      0      0
# 4                  11  ...      0      0      0      0      0      0      0
# 5                  48  ...      0      1      0      0      1      1      1
# ...

# %%
chi2, p, dof, expected = scipy.stats.chi2_contingency(table)
print(f"Chi2 Statestic:       {chi2: .5g}")
print(f"p-value:              {p: .5g}")
print(f"Degree of Freedom:    {dof}")
print(f"Expected Frequency:   {expected}")
# Out:
# Chi2 Statestic:        2552.3
# p-value:               2.6544e-24
# Degree of Freedom:    1866
# Expected Frequency:   [[3.75939850e-03 2.63157895e-02 9.39849624e-02 ... 3.75939850e-03
#   3.75939850e-03 3.75939850e-03]
#  [2.87593985e-02 2.01315789e-01 7.18984962e-01 ... 2.87593985e-02
#   2.87593985e-02 2.87593985e-02]
#  [3.41165414e-01 2.38815789e+00 8.52913534e+00 ... 3.41165414e-01
#   3.41165414e-01 3.41165414e-01]
#  ...
#  [1.29511278e-01 9.06578947e-01 3.23778195e+00 ... 1.29511278e-01
#   1.29511278e-01 1.29511278e-01]
#  [2.46240602e-02 1.72368421e-01 6.15601504e-01 ... 2.46240602e-02
#   2.46240602e-02 2.46240602e-02]
#  [9.39849624e-04 6.57894737e-03 2.34962406e-02 ... 9.39849624e-04
#   9.39849624e-04 9.39849624e-04]]

# %% [markdown]
# ##### 14. Create a new column as the acidity level. Divide the existing data into 5 groups based on the acidity level. The levels are to be named ['High', 'Moderately_High', 'Medium', 'Low']. Acidity may be obtained from the PH.

# %%
# Adding new categorical column!
# Bin edges that will be used to "cut" the data into groups
# Labels for the four acidity level groups - min/25%/50%/75%/max
# Creates new 'acidity_levels' column
# Checks for successful creation of this column

bin_edges = [2.72,3.11,3.21,3.32,4.01] 
bin_names = ['very_high','high','medium','low'] 
df_wine['acidity_levels'] = pd.cut(df_wine['pH'], bin_edges, labels=bin_names)
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.64         0.09             1.9      0.076
# 1               7.8              0.64         0.09             2.6      0.091
# 2               7.8              0.64         0.09             2.3      0.091
# 3               9.2              0.39         0.43             1.9      0.075
# 4               7.4              0.64         0.09             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# 5317            6.5              0.24         0.19             1.2      0.041
# 5318            5.5              0.29         0.30             1.1      0.022
# 5319            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ##### 15.Find the mean quality of each acidity level with groupby. Use groupby

# %%
df_wine.groupby(['quality','pH']).mean()
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/2592858565.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wine.groupby(['quality','pH']).mean()
#               fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality pH
# 3       2.87           7.90              0.64         0.46            10.6
#         2.89          10.30              0.17         0.47             1.4
#         2.90           9.40              0.24         0.29             8.5
#         2.93          11.80              0.23         0.38            11.1
#         3.02           8.50              0.26         0.21            16.2
# ...                     ...               ...          ...             ...
# 8       3.59           5.30              0.24         0.33             1.3
# ...

# %% [markdown]
# ##### 16. Is a certain type of wine (red or white) associated with higher quality?

# %%
# Q. Is a certain type of wine (red or white) associated with higher quality?:
# Find the mean quality of each wine type (red and white) with groupby

df_wine.groupby('color').mean()
# Out:
# C:\Users\omkar narkar\AppData\Local\Temp/ipykernel_12532/1106442356.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wine.groupby('color').mean()
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# color
# red         8.081089          0.515802     0.260824        2.230831
# white       6.839346          0.280538     0.334332        5.914819
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# color
# red     0.079943            13.894776             40.757910  0.996702
# white   0.045905            34.889169            137.193512  0.993790
#
#              pH  sulphates    alcohol   quality
# color
# red    3.306284   0.632781  10.261491  5.529065
# white  3.195458   0.490351  10.589358  5.854835

# %% [markdown]
# ##### 17. Select samples with alcohol content less than the median

# %%
a_median = df_wine['alcohol'].median()
a_low = df_wine.query('alcohol < {}'.format(a_median))
a_low
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.640         0.09            1.90      0.076
# 1               7.8             0.640         0.09            2.60      0.091
# 2               7.8             0.640         0.09            2.30      0.091
# 3               9.2             0.390         0.43            1.90      0.075
# 4               7.4             0.640         0.09            1.90      0.075
# ...             ...               ...          ...             ...        ...
# 5310            6.8             0.220         0.36            1.20      0.052
# 5311            4.9             0.235         0.27           11.75      0.030
# 5314            6.5             0.230         0.38            1.30      0.032
# 5316            6.6             0.320         0.36            8.00      0.047
# 5317            6.5             0.240         0.19            1.20      0.041
#
# ...

# %% [markdown]
# ##### 18. Get the quality rating for the low alcohol and high alcohol groups.

# %%
a_median = df_wine['alcohol'].median()

a_low = df_wine.query('alcohol < {}'.format(a_median))
a_high = df_wine.query('alcohol >= {}'.format(a_median))

mean_qual_low = a_low['quality'].mean()
mean_qual_high = a_high['quality'].mean()
print('The quality rating for the low alcohol group is ',mean_qual_low)
print('The quality rating for the high alcohol group is ',mean_qual_high)
# Out:
# The quality rating for the low alcohol group is  5.446106635980054
# The quality rating for the high alcohol group is  6.084408403980833

# %% [markdown]
# ##### 19. Do sweeter wines get more ratings?

# %%
low_sugar = df_wine[df_wine['residual sugar'] < 3] 
high_sugar = df_wine[df_wine['residual sugar'] >= 3]

# %%
#get mean quality rating for the low sugar and high sugar groups

low_sugar['quality'].mean() #5.80
high_sugar['quality'].mean() #5.82
# Out:
# 5.815450643776824

# %%
## plotting ##
##############
# Create a visualization to display our findings regarding the associations b/w quality and some properties
# ABOUT--- Q1: Is a certain type of wine (red or white) associated with higher quality?:

df_wine.groupby('color')['quality'].mean().plot(kind='bar', title='Avg Quality by Color', color = ['red', 'gray'] , alpha=0.7)
# Out:
# <AxesSubplot:title={'center':'Avg Quality by Color'}, xlabel='color'>

# %% [markdown]
# ##### 20. Get the number of counts based on ratings and color of wine.

# %%
counts = df_wine.groupby(['quality', 'color']).count();counts
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality color
# 3       white             20                20           20              20
# 4       white            153               153          153             153
# 5       red              640               640          640             640
#         white           1175              1175         1175            1175
# 6       red              719               719          719             719
#         white           1788              1788         1788            1788
# 7       white            689               689          689             689
# 8       white            131               131          131             131
# 9       white              5                 5            5               5
#
#                chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# quality color
# 3       white         20                   20                    20       20
# ...

# %%
# plot!

colors=['red', 'gray'] 

counts = df_wine.groupby(['quality', 'color']).count()['pH']  #the values for all columns are the same...coz it's a count! 
counts.plot(kind='bar', title='Avg Quality by Color', color=colors)

plt.xlabel('Quality + Colors', fontsize=18) 
plt.ylabel('Count', fontsize=18)
# Out:
# Text(0, 0.5, 'Count')

# %%
# there are clearly more white samples than red samples. so it's hard to make a fair comparison. To balance this out, we can 
#divide each count by the total count for that color to use "proportions" instead.

colors=['red', 'gray'] 

counts = df_wine.groupby(['quality', 'color']).count()['pH']  #the values for all columns are the same...coz it's a count! 
total = df_wine.groupby('color').count()['pH']

prop = counts / total
prop.plot(kind='bar', title='Avg Quality by Color', color=colors)

plt.xlabel('Quality + Colors', fontsize=18) 
plt.ylabel('Proportion', fontsize=18)

#As can be seen, for the lower ratings -3/4/5, 'red' shows higher proportion. and for the higher ratings, the reverse is true.
# Out:
# Text(0, 0.5, 'Proportion')

# %% [markdown]
# ##### 21. Is the density of red wine and white wine similar?

# %%
 # Import the library
import scipy.stats as stats
 
# Creating data groups
x = df_red['density']
y = df_white['density']
 
# Perform the two sample t-test with equal variances
stats.ttest_ind(a=x, b=y, equal_var=True)
# Out:
# Ttest_indResult(statistic=36.37412311800399, pvalue=6.632511270246229e-259)

# %% [markdown]
# H0 => µ1 = µ2 (population mean of dataset1 is equal to dataset2)
#
# HA => µ1 ≠µ2 (population mean of dataset1 is different from dataset2)
#
# Here, since the p-value (6.6325) is greater than alpha = 0.05 so we cannot reject the null hypothesis of the test. We do not have sufficient evidence to say that the mean height of students between the two data groups is different.

# %%
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.64         0.09             1.9      0.076
# 1               7.8              0.64         0.09             2.6      0.091
# 2               7.8              0.64         0.09             2.3      0.091
# 3               9.2              0.39         0.43             1.9      0.075
# 4               7.4              0.64         0.09             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# 5317            6.5              0.24         0.19             1.2      0.041
# 5318            5.5              0.29         0.30             1.1      0.022
# 5319            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ##### 22. Is the confidence interval for the differences of the proportion of white wine with rating 3 and the proportion of red wine with rating 3.

# %%
from statsmodels.stats.weightstats import ztest as ztest

white_count = df_wine[(df_wine['color'] == 'white') & (df_wine['quality'] == 3)].shape[0]
red_count = df_wine[(df_wine['color'] == 'red') & (df_wine['quality'] == 3)].shape[0]
print('Number of red color wine having rating 3:',red_count)

#perform two sample z-test
#ztest(white_count, red_count, value=0)
# Out:
# Number of red color wine having rating 3: 0

# %% [markdown]
# Number of red color wine having rating 3: 0
#
# hence, can not perform z test
